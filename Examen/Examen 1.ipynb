# %% [markdown]
# **Examen**

# %% [markdown]
# Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Cargar pais sin nulos

# %%
df = pd.read_csv("Naples_sin_nulos.csv")
df
# Out:
#        Unnamed: 0            id last_scraped  \
# 0               0  3.046600e+04   17/09/2024
# 1               1  3.053600e+04   17/09/2024
# 2               2  6.341300e+04   17/09/2024
# 3               3  7.436400e+04   17/09/2024
# 4               4  7.699300e+04   17/09/2024
# ...           ...           ...          ...
# 11022       11022  1.240000e+18   17/09/2024
# 11023       11023  1.240000e+18   17/09/2024
# 11024       11024  1.240000e+18   17/09/2024
# 11025       11025  1.250000e+18   17/09/2024
# 11026       11026  1.250000e+18   17/09/2024
#
#                                                     name  \
# 0                   Naturists rooms in the heart of city
# 1                            cosy room to let  in naples
# 2                     Charming Room on Riviera di Chiaia
# 3        Cozy place in a princely Palace inside Old Town
# 4      Central Cebollitas B&B, spacious private ensuite.
# ...                                                  ...
# ...

# %%
df1 = df.drop(['Unnamed: 0'], axis=1)
df1
# Out:
#                  id last_scraped  \
# 0      3.046600e+04   17/09/2024
# 1      3.053600e+04   17/09/2024
# 2      6.341300e+04   17/09/2024
# 3      7.436400e+04   17/09/2024
# 4      7.699300e+04   17/09/2024
# ...             ...          ...
# 11022  1.240000e+18   17/09/2024
# 11023  1.240000e+18   17/09/2024
# 11024  1.240000e+18   17/09/2024
# 11025  1.250000e+18   17/09/2024
# 11026  1.250000e+18   17/09/2024
#
#                                                     name  \
# 0                   Naturists rooms in the heart of city
# 1                            cosy room to let  in naples
# 2                     Charming Room on Riviera di Chiaia
# 3        Cozy place in a princely Palace inside Old Town
# 4      Central Cebollitas B&B, spacious private ensuite.
# ...                                                  ...
# 11022                           Domus Parthenope Confort
# 11023                                      Casetta lulÃ¹
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11027 entries, 0 to 11026
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           11027 non-null  float64
#  1   last_scraped                 11027 non-null  object
#  2   name                         11027 non-null  object
#  3   description                  11027 non-null  object
#  4   neighborhood_overview        11027 non-null  object
#  5   picture_url                  11027 non-null  object
#  6   host_name                    11027 non-null  object
#  7   host_since                   11027 non-null  object
#  8   host_about                   11027 non-null  object
#  9   host_response_time           11027 non-null  object
#  10  host_response_rate           11027 non-null  float64
#  11  host_acceptance_rate         11027 non-null  float64
# ...

# %% [markdown]
# el host se haya unido desde el 01 de enero de 2015 o que tengan mas de dos baños

# %%
filtro1 = df1[(df1["host_since"] >= "2015-01-01") | (df1["bedrooms"] > 2) ]
filtro1
# Out:
#                  id last_scraped  \
# 4      7.699300e+04   17/09/2024
# 5      7.700900e+04   17/09/2024
# 6      7.701000e+04   17/09/2024
# 7      1.375870e+05   17/09/2024
# 8      1.576910e+05   17/09/2024
# ...             ...          ...
# 11020  1.240000e+18   17/09/2024
# 11022  1.240000e+18   17/09/2024
# 11024  1.240000e+18   17/09/2024
# 11025  1.250000e+18   17/09/2024
# 11026  1.250000e+18   17/09/2024
#
#                                                     name  \
# 4      Central Cebollitas B&B, spacious private ensuite.
# 5       Central Cebollitas B&B Napoli,single/double room
# 6           central Cebollitas B&B , large single/double
# 7         Napoli Cardinalâs house Duomo centro storico
# 8                                  Friendly little house
# ...                                                  ...
# 11020                                    A casa di MarÃ¬
# 11022                           Domus Parthenope Confort
# ...
